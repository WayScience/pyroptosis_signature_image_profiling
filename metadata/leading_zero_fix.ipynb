# %%
# fix leading zeros in the metadata
# imports
import pandas as pd
import numpy as np

# %%
# read in the metadata file
metadata = pd.read_csv('Interstellar_plate2_platemap.csv')

# fix the leading zeros in the well_id column after the letter
metadata['well_id'] = metadata['well_id'].apply(lambda x: x[0] + x[1:].zfill(2))

# save the metadata file
metadata.to_csv('Interstellar_plate2_platemap.csv', index=False)
metadata
# Out:
#     well_id cell_type  incubation inducer (h) inhibitor  \
# 0       A01       NaN                       6       NaN
# 1       B01       NaN                       6       NaN
# 2       C01       NaN                       6       NaN
# 3       D01       NaN                       6       NaN
# 4       E01       NaN                       6       NaN
# ..      ...       ...                     ...       ...
# 379     L24       NaN                       6       NaN
# 380     M24       NaN                       6       NaN
# 381     N24       NaN                       6       NaN
# 382     O24       NaN                       6       NaN
# 383     P24       NaN                       6       NaN
#
#      inhibitor_concentration inhibitor_concentration_unit inducer1  \
# 0                        NaN                          NaN      NaN
# 1                        NaN                          NaN      NaN
# 2                        NaN                          NaN      NaN
# ...
