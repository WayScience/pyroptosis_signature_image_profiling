# %% [markdown]
# ## Nucleus morphology UMAP

# %%
import pathlib
import pandas as pd

from pycytominer import normalize, feature_select
from pycytominer.cyto_utils import infer_cp_features

import umap

# %%
# Focus on gasdermin cols
gasdermin_cols = [
    "TranslocatedNuclei_Intensity_IntegratedIntensity_CorrGasderminD",
    "DilatedNuclei_Intensity_IntegratedIntensity_CorrGasderminD",
    "TranslocatedNuclei_Neighbors_NumberOfNeighbors_Expanded"
]

# %%
# Load single cell profiles
feature_dir = pathlib.Path("..", "3.process_features", "data")

# This determines the file
file_prefix = "interstellar_wave1_dilate"
file_suffix = "_sc.csv.gz"
dilation_factor = 50

cp_file = pathlib.Path(feature_dir, f"{file_prefix}{dilation_factor}{file_suffix}")
output_umap_file = pathlib.Path("results", f"umap_embeddings_dilation{dilation_factor}.csv.gz")

# Load data
cp_df = pd.read_csv(cp_file, low_memory=False)

# Remove outliers
cp_df = (
    cp_df
    .query("DilatedNuclei_Intensity_IntegratedIntensity_CorrGasderminD < 100")
    .reset_index(drop=True)
)

print(cp_df.shape)
cp_df.head()
# Out:
# (17296, 841)
#   Metadata_wellName  Metadata_row  Metadata_col  Metadata_alias  \
# 0               A10             1            10               9
# 1               A10             1            10               9
# 2               A10             1            10               9
# 3               A10             1            10               9
# 4               A10             1            10               9
#
#   Metadata_treatment Metadata_dose  Metadata_ImageNumber  \
# 0         Disulfiram         2.5µM                    19
# 1         Disulfiram         2.5µM                    19
# 2         Disulfiram         2.5µM                    19
# 3         Disulfiram         2.5µM                    19
# 4         Disulfiram         2.5µM                    19
#
#                  Metadata_Plate Metadata_Well  \
# 0  70117_20230118MM1_Ab Test_V2           A10
# 1  70117_20230118MM1_Ab Test_V2           A10
# 2  70117_20230118MM1_Ab Test_V2           A10
# 3  70117_20230118MM1_Ab Test_V2           A10
# 4  70117_20230118MM1_Ab Test_V2           A10
#
#    Metadata_TranslocatedNuclei_Parent_DilatedNuclei  ...  \
# 0                                                 1  ...
# 1                                                 4  ...
# 2                                                 2  ...
# 3                                                 3  ...
# 4                                                 5  ...
#
#    Nuclei_Texture_SumVariance_CorrGasderminD_3_02_256  \
# 0                                           0.562764
# 1                                           0.562764
# 2                                           0.606445
# 3                                           0.630966
# 4                                           0.635611
#
#    Nuclei_Texture_SumVariance_CorrGasderminD_3_03_256  \
# 0                                           0.519955
# 1                                           0.519955
# 2                                           0.583598
# 3                                           0.607802
# 4                                           0.585116
#
#    Nuclei_Texture_Variance_CorrDNA_3_00_256  \
# 0                                  5.453863
# 1                                  5.453863
# 2                                  1.243379
# 3                                  1.578343
# 4                                  3.693021
#
#    Nuclei_Texture_Variance_CorrDNA_3_01_256  \
# 0                                  5.338515
# 1                                  5.338515
# 2                                  1.224368
# 3                                  1.586902
# 4                                  3.615390
#
#    Nuclei_Texture_Variance_CorrDNA_3_02_256  \
# 0                                  5.496212
# 1                                  5.496212
# 2                                  1.241659
# 3                                  1.568943
# 4                                  3.755390
#
#    Nuclei_Texture_Variance_CorrDNA_3_03_256  \
# 0                                  5.341068
# 1                                  5.341068
# 2                                  1.238014
# 3                                  1.577166
# 4                                  3.691136
#
#    Nuclei_Texture_Variance_CorrGasderminD_3_00_256  \
# 0                                         0.208618
# 1                                         0.208618
# 2                                         0.248763
# 3                                         0.249089
# 4                                         0.240287
#
#    Nuclei_Texture_Variance_CorrGasderminD_3_01_256  \
# 0                                         0.205860
# 1                                         0.205860
# 2                                         0.246857
# 3                                         0.249433
# 4                                         0.240656
#
#    Nuclei_Texture_Variance_CorrGasderminD_3_02_256  \
# 0                                         0.207914
# 1                                         0.207914
# 2                                         0.247815
# 3                                         0.249490
# 4                                         0.240940
#
#    Nuclei_Texture_Variance_CorrGasderminD_3_03_256
# 0                                         0.203880
# 1                                         0.203880
# 2                                         0.248309
# 3                                         0.249476
# 4                                         0.242418
#
# [5 rows x 841 columns]

# %%
# Process only the nucleus features through the pipeline
# Remove all information from gasdermin channel
nucleus_features = infer_cp_features(cp_df, compartments="Nuclei")
nucleus_features = [x for x in nucleus_features if "Gasdermin" not in x]

metadata_features = infer_cp_features(cp_df, metadata=True)

cp_norm_fs_df = normalize(
    profiles=cp_df,
    features=nucleus_features,
    method="standardize"
)

ops = [
    "variance_threshold",
    "correlation_threshold",
    "blocklist",
    "drop_na_columns"
]
cp_norm_fs_df = feature_select(
    profiles=cp_norm_fs_df,
    features=nucleus_features,
    operation=ops,
    na_cutoff=0
)

print(cp_norm_fs_df.shape)
cp_norm_fs_df.head()
# Out:
# (17296, 89)
#   Metadata_wellName  Metadata_row  Metadata_col  Metadata_alias  \
# 0               A10             1            10               9
# 1               A10             1            10               9
# 2               A10             1            10               9
# 3               A10             1            10               9
# 4               A10             1            10               9
#
#   Metadata_treatment Metadata_dose  Metadata_ImageNumber  \
# 0         Disulfiram         2.5µM                    19
# 1         Disulfiram         2.5µM                    19
# 2         Disulfiram         2.5µM                    19
# 3         Disulfiram         2.5µM                    19
# 4         Disulfiram         2.5µM                    19
#
#                  Metadata_Plate Metadata_Well  \
# 0  70117_20230118MM1_Ab Test_V2           A10
# 1  70117_20230118MM1_Ab Test_V2           A10
# 2  70117_20230118MM1_Ab Test_V2           A10
# 3  70117_20230118MM1_Ab Test_V2           A10
# 4  70117_20230118MM1_Ab Test_V2           A10
#
#    Metadata_TranslocatedNuclei_Parent_DilatedNuclei  ...  \
# 0                                                 1  ...
# 1                                                 4  ...
# 2                                                 2  ...
# 3                                                 3  ...
# 4                                                 5  ...
#
#    Nuclei_Texture_Correlation_CorrDNA_3_00_256  \
# 0                                     0.860423
# 1                                     0.860423
# 2                                    -1.254840
# 3                                    -0.037423
# 4                                    -1.386999
#
#    Nuclei_Texture_Correlation_CorrDNA_3_01_256  \
# 0                                     0.845928
# 1                                     0.845928
# 2                                    -1.631391
# 3                                    -0.213935
# 4                                    -1.839468
#
#    Nuclei_Texture_Correlation_CorrDNA_3_02_256  \
# 0                                     0.722466
# 1                                     0.722466
# 2                                    -2.007997
# 3                                    -0.883704
# 4                                    -1.384641
#
#    Nuclei_Texture_Correlation_CorrDNA_3_03_256  \
# 0                                     0.688251
# 1                                     0.688251
# 2                                    -1.616413
# 3                                    -0.072768
# 4                                    -1.373801
#
#    Nuclei_Texture_DifferenceEntropy_CorrDNA_3_02_256  \
# 0                                           0.179948
# 1                                           0.179948
# 2                                          -0.369674
# 3                                          -0.417221
# 4                                           0.780289
#
#    Nuclei_Texture_DifferenceVariance_CorrDNA_3_03_256  \
# 0                                          -0.419181
# 1                                          -0.419181
# 2                                           0.622749
# 3                                           0.669601
# 4                                          -0.677501
#
#    Nuclei_Texture_InfoMeas1_CorrDNA_3_00_256  \
# 0                                  -0.558412
# 1                                  -0.558412
# 2                                   1.091174
# 3                                  -0.184422
# 4                                   1.669752
#
#    Nuclei_Texture_InfoMeas1_CorrDNA_3_01_256  \
# 0                                  -0.422113
# 1                                  -0.422113
# 2                                   1.518552
# 3                                   0.163880
# 4                                   1.603315
#
#    Nuclei_Texture_InfoMeas1_CorrDNA_3_02_256  \
# 0                                  -0.319445
# 1                                  -0.319445
# 2                                   1.752610
# 3                                   0.749631
# 4                                   1.717936
#
#    Nuclei_Texture_InfoMeas1_CorrDNA_3_03_256
# 0                                  -0.303139
# 1                                  -0.303139
# 2                                   1.497787
# 3                                   0.088193
# 4                                   1.470230
#
# [5 rows x 89 columns]

# %%
# Fit UMAP
cp_feature_df = cp_norm_fs_df.drop(metadata_features, axis="columns")

umap_fit = umap.UMAP(random_state=42, n_components=2)

embeddings_df = pd.DataFrame(
    umap_fit.fit_transform(cp_feature_df), columns=["UMAP0", "UMAP1"]
)

embeddings_df = pd.concat([
    cp_norm_fs_df.loc[:, metadata_features],
    embeddings_df,
    cp_df.loc[:, gasdermin_cols]
], axis="columns")

dose_recode = {
    "0": "low",
    "0.1µM": "low",
    "1µM": "low",
    "1µg/ml + 1µM": "low",
    "2.5µM": "high",
    "10µM": "high",
    "1µg/ml + 10µM": "high"
}
embeddings_df = embeddings_df.assign(
    Metadata_dose_recode=embeddings_df.Metadata_dose.replace(dose_recode)
)

# Output file
embeddings_df.to_csv(output_umap_file, index=False)

print(embeddings_df.shape)
embeddings_df.head()
# Out:
# (17296, 19)
#   Metadata_wellName  Metadata_row  Metadata_col  Metadata_alias  \
# 0               A10             1            10               9
# 1               A10             1            10               9
# 2               A10             1            10               9
# 3               A10             1            10               9
# 4               A10             1            10               9
#
#   Metadata_treatment Metadata_dose  Metadata_ImageNumber  \
# 0         Disulfiram         2.5µM                    19
# 1         Disulfiram         2.5µM                    19
# 2         Disulfiram         2.5µM                    19
# 3         Disulfiram         2.5µM                    19
# 4         Disulfiram         2.5µM                    19
#
#                  Metadata_Plate Metadata_Well  \
# 0  70117_20230118MM1_Ab Test_V2           A10
# 1  70117_20230118MM1_Ab Test_V2           A10
# 2  70117_20230118MM1_Ab Test_V2           A10
# 3  70117_20230118MM1_Ab Test_V2           A10
# 4  70117_20230118MM1_Ab Test_V2           A10
#
#    Metadata_TranslocatedNuclei_Parent_DilatedNuclei  \
# 0                                                 1
# 1                                                 4
# 2                                                 2
# 3                                                 3
# 4                                                 5
#
#    Metadata_TranslocatedNuclei_Parent_Nuclei  \
# 0                                          1
# 1                                          1
# 2                                          2
# 3                                          3
# 4                                          4
#
#    Metadata_DilatedNuclei_Number_Object_Number  \
# 0                                            1
# 1                                            4
# 2                                            2
# 3                                            3
# 4                                            5
#
#    Metadata_Nuclei_Number_Object_Number      UMAP0     UMAP1  \
# 0                                     1   9.128251  8.581470
# 1                                     1   9.154372  8.578030
# 2                                     2   5.802378  4.135841
# 3                                     3  10.566055  0.882976
# 4                                     4   8.293353  1.635236
#
#    TranslocatedNuclei_Intensity_IntegratedIntensity_CorrGasderminD  \
# 0                                          17.836798
# 1                                          15.104700
# 2                                          14.489743
# 3                                          42.425449
# 4                                          35.623372
#
#    DilatedNuclei_Intensity_IntegratedIntensity_CorrGasderminD  \
# 0                                          19.612568
# 1                                          15.497138
# 2                                          19.689052
# 3                                          62.860749
# 4                                          57.850413
#
#    TranslocatedNuclei_Neighbors_NumberOfNeighbors_Expanded  \
# 0                                                  3
# 1                                                  5
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#   Metadata_dose_recode
# 0                 high
# 1                 high
# 2                 high
# 3                 high
# 4                 high
