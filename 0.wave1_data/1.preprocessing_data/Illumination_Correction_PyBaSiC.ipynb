# %% [markdown]
# # Illumination Correction of NF1 Images

# %% [markdown]
# ## Import libraries

# %%
import sys
import numpy as np
import pathlib
from matplotlib import pyplot as plt
from pathlib import Path
import os
import skimage

# explicit import to PyBaSiC due to not having package support
sys.path.append("./PyBaSiC/")
import pybasic

# %% [markdown]
# ## Helper functions to run PyBaSiC illumination correction
# - Allows for PyBaSiC to be run on any image sets and only need to input the path to the directory with the channel folders and the folder name of the channel that you
# want to work with.

# %%
def load_pybasic_data(
    channels_path: pathlib.Path,
    channel: str,
    file_extension=".tif",
    verbosity: bool = True,
):
    """
    Load all images from a specified directory in preparation for pybasic illum correction

    Parameters:
    channels_path (pathlib.Path): path to directory where the all images for each channel are stored
    channel (str): The name of the channel
    file_extension (str): The filename extension of the types of files to search for (default: ".tif")
    verbosity (bool): Prints out information regarding the function running through the images (default: "True")

    Returns:
        channel_images: list of ndarrays of the loaded in images
        image_files: list of strings of the paths to each image
    """
    image_files = (
        []
    )  # List that holds all of the paths to the images in the directory for a specific channel
    image_names = (
        []
    )  # List that holds the names (str) for the images that is used for saving
    images = []  # List of numpy arrays for the images that are read in

    # This for loop will run through the specified directory, find images for a specific channel (channel name is in the file name metadata),
    # save paths to a list, and then save the names to a list after stripping the file_extension
    for image_path in channels_path.iterdir():
        image_path = str(image_path)
        if channel in image_path:
            image_files.append(image_path)
            if image_path.endswith(file_extension):
                image_names.append(image_path.strip(file_extension))

    # Sorts the file paths and names into alphabetical order (puts well C at the start)
    image_files.sort()
    image_names.sort()

    # This for loop will run through the paths to the images for the specified channel and load in the images to be used to illumination correction
    # This code was sampled from the `load_data` function in PyBaSiC
    for i, image_file in enumerate(image_files):
        if verbosity and (i % 10 == 0):
            print(i, "/", len(image_files))
        images.append(skimage.io.imread(image_file))

    return images, image_names


def run_illum_correct(
    channels_path: pathlib.Path,
    save_path: pathlib.Path,
    channel: str,
    output_calc: bool = False,
    file_extension: str = ".tif",
):
    """calculates flatfield, darkfield, performs illumination correction on channel images, coverts to 8-bit and saves images into designated folder

    Parameters:
        channels_path (pathlib.Path): path to directory where the all images for each channel are stored
        save_path (pathlib.Path): path to directory where the corrected images will be saved to
        channel (str): name of channel
        output_calc (bool): outputs plots of the flatfield and darkfield function for visual review if set to 'True'
        file_extension (str): The filename extension of the types of files to search for (default: ".tif")
    """
    # Loads in the variables returned from "load_pybasic_data" function
    images, image_names = load_pybasic_data(channels_path, channel, file_extension)

    print("Correcting", {channel})

    flatfield, darkfield = pybasic.basic(images, darkfield=True)

    # Optional output that displays the plots for the flatfield and darkfield calculations if set to True (default is False)
    if output_calc == True:
        plt.title("Flatfield")
        plt.imshow(flatfield)
        plt.colorbar()
        plt.show()
        plt.title("Darkfield")
        plt.imshow(darkfield)
        plt.colorbar()
        plt.show()

    # Run PyBaSiC illumination correction function on loaded in images
    channel_images_corrected = pybasic.correct_illumination(
        images_list=images,
        flatfield=flatfield,
        darkfield=darkfield,
    )

    # Covert illum corrected images to uint8 for downstream analysis
    corrected_images_coverted = np.array(channel_images_corrected)
    corrected_images_coverted[
        corrected_images_coverted < 0
    ] = 0  # makes the negatives 0
    corrected_images_coverted = corrected_images_coverted / np.max(
        corrected_images_coverted
    )  # normalize the data to 0 - 1
    corrected_images_coverted = 255 * corrected_images_coverted  # Scale by 255
    corrected_images = corrected_images_coverted.astype(np.uint8)

    for i, image in enumerate(corrected_images):
        orig_file = image_names[i]
        orig_file_name = orig_file.split("/")[4]
        new_filename = pathlib.Path(f"{save_path}/{orig_file_name}_IllumCorrect.tif")

        # If the image has not been correcrted yet, then the function will save the image. If the image exists, it will skip saving.
        if not new_filename.is_file():
            skimage.io.imsave(new_filename, image)

        else:
            print(f"{new_filename.name} already exists!")

# %% [markdown]
# ### Implementing helper functions to run illumination correction on each channel for NF1 data

# %%
# Set location of input and output locations
channel_path = pathlib.Path("../0.download_data/70117_20230118MM1_Ab Test_V2__2023-01-25T16_44_54-Measurement1/Images")

save_path = pathlib.Path("Corrected_Images")

# Channels to process
channels = ["ch1", "ch2"]

# Perform illumination correction on each channel seperately using a `for` loop:
for channel in channels:
    # print(channel)
    print("Correcting", channel, "channel images")

    # If you want to output the flatfield and darkfield calculations, then put "output_calc=True".
    # If not, leave out from function since it is defaulted to False

    run_illum_correct(
        channel_path,
        save_path,
        channel=channel,
        output_calc=False,
        file_extension=".tiff"
    )
# Out:
# Correcting ch1 channel images
# 0 / 192
# 10 / 192
# 20 / 192
# 30 / 192
# 40 / 192
# 50 / 192
# 60 / 192
# 70 / 192
# 80 / 192
# 90 / 192
# 100 / 192
# 110 / 192
# 120 / 192
# 130 / 192
# 140 / 192
# 150 / 192
# 160 / 192
# 170 / 192
# 180 / 192
# 190 / 192
# Correcting {'ch1'}
# reweighting_iter: 1
# /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/./PyBaSiC/pybasic/tools/inexact_alm_rspca_l1.py:118: RuntimeWarning: divide by zero encountered in scalar divide
#   B1_offset = np.minimum(B1_offset, B1_uplimit / np.mean(W_idct_hat))
# reweighting_iter: 2
# reweighting_iter: 3
# reweighting_iter: 4
# reweighting_iter: 5
# reweighting_iter: 6
# reweighting_iter: 7
# reweighting_iter: 8
# reweighting_iter: 9
# reweighting_iter: 10
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c04f01p01-ch1sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c04f01p02-ch1sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c04f01p03-ch1sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# Correcting ch2 channel images
# 0 / 192
# 10 / 192
# 20 / 192
# 30 / 192
# 40 / 192
# 50 / 192
# 60 / 192
# 70 / 192
# 80 / 192
# 90 / 192
# 100 / 192
# 110 / 192
# 120 / 192
# 130 / 192
# 140 / 192
# 150 / 192
# 160 / 192
# 170 / 192
# 180 / 192
# 190 / 192
# Correcting {'ch2'}
# reweighting_iter: 1
# reweighting_iter: 2
# reweighting_iter: 3
# reweighting_iter: 4
# reweighting_iter: 5
# reweighting_iter: 6
# reweighting_iter: 7
# reweighting_iter: 8
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c03f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c03f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c03f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c03f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c03f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c03f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c04f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c04f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c04f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c04f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c04f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c04f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c09f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c09f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c09f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c09f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c09f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c09f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c10f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c10f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c10f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c10f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c10f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r01c10f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c03f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c03f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c03f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c03f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c03f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c03f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c04f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c04f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c04f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c04f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c04f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c04f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c09f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c09f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c09f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c09f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c09f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c09f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c10f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c10f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c10f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c10f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c10f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r02c10f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c03f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c03f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c03f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c03f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c03f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c03f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c04f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c04f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c04f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c04f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c04f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c04f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c09f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c09f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c09f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c09f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c09f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c09f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c10f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c10f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c10f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c10f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c10f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r03c10f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c03f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c03f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c03f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c03f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c03f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c03f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c04f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c04f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c04f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c04f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c04f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c04f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c09f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c09f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c09f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c09f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c09f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c09f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c10f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c10f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c10f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c10f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c10f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r04c10f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c03f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c03f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c03f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c03f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c03f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c03f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c04f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c04f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c04f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c04f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c04f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c04f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c09f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c09f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c09f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c09f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c09f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c09f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c10f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c10f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c10f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c10f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c10f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r05c10f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c03f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c03f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c03f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c03f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c03f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c03f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c04f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c04f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c04f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c04f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c04f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c04f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c09f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c09f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c09f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c09f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c09f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c09f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c10f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c10f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c10f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c10f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c10f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r06c10f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c03f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c03f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c03f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c03f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c03f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c03f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c04f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c04f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c04f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c04f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c04f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c04f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c09f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c09f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c09f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c09f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c09f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c09f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c10f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c10f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c10f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c10f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c10f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r07c10f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c03f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c03f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c03f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c03f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c03f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c03f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c04f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c04f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c04f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c04f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c04f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c04f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c09f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c09f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c09f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c09f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c09f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c09f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c10f01p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c10f01p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c10f01p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c10f02p01-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c10f02p02-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)
# /tmp/ipykernel_1130436/3099462909.py:110: UserWarning: /home/jenna/Desktop/Github/Interstellar_Project/0.wave1_data/1.preprocessing_data/Corrected_Images/r08c10f02p03-ch2sk1fk1fl1_IllumCorrect.tif is a low contrast image
#   skimage.io.imsave(new_filename, image)

# %% [markdown]
# ## Process of PyBaSiC Illumination Correction
# **Note:** This section shows the process in which the helper functions are based on.
#
# ### Create path and load in images
# The directory set up used for this experiment goes as such:
# ```
#
# ├── NF1_SchwannCell_data/
# │   ├── 0_download_data/
# │   │   ├── NF1_Images/
# │   ├── 1_preprocessing_data/
# │   │   ├── PyBaSiC_Pipelines/
# │   │   │   ├── Corrected_Images/
#
# ```

# %%
channels_path = pathlib.Path("../PyBaSiC_Pipelines/NF1_Channels/DAPI")
save_path = pathlib.Path("../Corrected_Images")
channel = "DAPI"
file_extension = ".tif"
# Prints out information regarding the function running through the images
verbosity = True

# The for loop is running through the images within the folder designated by channels_path and it will only take the images from a specific channel to save and use
# The load_data function within PyBaSiC is not used for this pipleine due to the function not being as generalizable

image_files = []
image_names = []
images = []

for image_path in channels_path.iterdir():
    image_path = str(image_path)
    if channel in image_path:
        image_files.append(image_path)
        if image_path.endswith(file_extension):
            image_names.append(image_path.strip(file_extension))

image_files.sort()
image_names.sort()

for i, image_file in enumerate(image_files):
    if verbosity and (i % 10 == 0):
        print(i, "/", len(image_files))
    images.append(skimage.io.imread(image_file))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 15
#      12 image_names = []
#      13 images = []
# ---> 15 for image_path in channels_path.iterdir():
#      16     image_path = str(image_path)
#      17     if channel in image_path:
#
# File ~/anaconda3/envs/1.preprocessing-interstellar/lib/python3.8/pathlib.py:1122, in Path.iterdir(self)
#    1120 if self._closed:
#    1121     self._raise_closed()
# -> 1122 for name in self._accessor.listdir(self):
#    1123     if name in {'.', '..'}:
#    1124         # Yielding a path object for these makes little sense
#    1125         continue
#
# FileNotFoundError: [Errno 2] No such file or directory: '../PyBaSiC_Pipelines/NF1_Channels/DAPI'

# %% [markdown]
# ### Run PyBaSiC to calculate the flatfield and darkfield

# %%
flatfield, darkfield = pybasic.basic(images, darkfield=True)

# %% [markdown]
# ### Displays the flatfield and darkfield that will be applied to the images

# %%
# Based on documentation from the developers, it is recommended to manually check the flatfield function created using the functions below.
# If the flatfield looks smooth, then the correction will be done well.
# If it is noisey, then there is likely an issue with the correction.
# Source: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5472168/

plt.title("Flatfield")
plt.imshow(flatfield)
plt.colorbar()
plt.show()
plt.title("Darkfield")
plt.imshow(darkfield)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Run illumination correction

# %%
channel_images_corrected = pybasic.correct_illumination(
    images_list=images,
    flatfield=flatfield,
    darkfield=darkfield,
)

# %% [markdown]
# ### Conversion of Corrected Images

# %%
# The default output for the corrected images was not compatable with downstream processes which required code to convert the images to `8-bit`. This code was
# utlized from Mitocheck Data Project - Preprocessing Training Data {https://github.com/WayScience/mitocheck_data/blob/main/1.preprocess_data/preprocess_training_data.ipynb}

corrected_images_coverted = np.array(channel_images_corrected)
corrected_images_coverted[corrected_images_coverted < 0] = 0  # makes the negatives 0
corrected_images_coverted = corrected_images_coverted / np.max(
    corrected_images_coverted
)  # normalize the data to 0 - 1
corrected_images_coverted = 255 * corrected_images_coverted  # Scale by 255
corrected_images = corrected_images_coverted.astype(np.uint8)

# %% [markdown]
# ### Use `for` loop that adds suffix to corrected images and downloads them

# %%
# Recommended to add a suffix that will indicate the which type of image it is, especially if the raw and corrected images look the same to the naked eye.

for i, image in enumerate(corrected_images):
    orig_file = image_names[i]
    orig_file_name = orig_file.split("/")[4]
    new_filename = pathlib.Path(f"{save_path}/{orig_file_name}_IllumCorrect.tif")
