# %% [markdown]
# # Process image features from CellProfiler readout

# %% [markdown]
# ## Import Libraries

# %%
import pathlib
import pandas as pd

from pycytominer import annotate
from pycytominer.cyto_utils import output

import sys
sys.path.append("../../utils")
import extract_image_features_utils as extract_utils

# %% [markdown]
# ## Set up paths to CellProfiler directory and outputs

# %%
# Set file and directory constants
cp_dir = "../3.cellprofiler_analysis"
output_dir = "data"

# %% [markdown]
# ## Set paths to sqlite files

# %%
# Set name and path of .sqlite file and path to metadata
sql_file = "interstellar_wave3_imagequality.sqlite"
single_cell_file = f"sqlite:///{cp_dir}/analysis_output/{sql_file}"
platemap_file = "../../metadata/Interstellar_platemap.csv"
image_table_name = "Per_Image"

# Set path with name for outputted data
image_features_output_file = pathlib.Path(f"{output_dir}/interstellar_wave3_imagequality.csv.gz")

# %% [markdown]
# ## Set variables for extracting image features

# %%
# Only ImageQuality category since the CellProfiler pipeline extract image quality measurements
image_feature_categories = ["Image_ImageQuality"]
image_cols="ImageNumber"
strata=["Image_Metadata_Well", "Image_Metadata_Plate"]

# %% [markdown]
# ## Load and view platemap file

# %%
# Load platemap file
platemap_df = pd.read_csv(platemap_file)
platemap_df.head()
# Out:
#   well wellName  row  col  alias treatment     dose
# 0  A01       A1    1    1      1       LPS  10µg/ml
# 1  B01       B1    2    1      2       LPS   1µg/ml
# 2  C01       C1    3    1      3      H2O2    500µM
# 3  D01       D1    4    1      4      H2O2     50µM
# 4  E01       E1    5    1      5       ATP      1mM

# %% [markdown]
# ## Load in sqlite file

# %%
image_df = extract_utils.load_sqlite_as_df(single_cell_file, image_table_name)

print(image_df.shape)
image_df.head()
# Out:
# (960, 309)
#    ImageNumber  Image_ExecutionTime_01LoadData  \
# 0            1                            3.08
# 1            2                            5.04
# 2            3                            5.00
# 3            4                            5.39
# 4            5                            4.66
#
#    Image_ExecutionTime_02CorrectIlluminationApply  \
# 0                                            0.09
# 1                                            0.70
# 2                                            0.89
# 3                                            0.88
# 4                                            1.02
#
#    Image_ExecutionTime_03MeasureImageQuality  \
# 0                                      21.65
# 1                                      49.37
# 2                                      49.69
# 3                                      48.10
# 4                                      50.02
#
#                              Image_FileName_IllumDNA  \
# 0  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 1  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 2  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 3  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 4  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
#
#                               Image_FileName_IllumER  \
# 0  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 1  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 2  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 3  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 4  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
#
#                        Image_FileName_IllumGasdermin  \
# 0  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 1  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 2  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 3  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 4  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
#
#                             Image_FileName_IllumMito  \
# 0  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 1  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 2  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 3  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 4  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
#
#                               Image_FileName_IllumPM  \
# 0  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 1  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 2  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 3  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
# 4  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...
#
#                              Image_FileName_IllumRNA  ...  \
# 0  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...  ...
# 1  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...  ...
# 2  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...  ...
# 3  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...  ...
# 4  70117_20230118MM1_CellPainting_A700_20X_V1_Ill...  ...
#
#   Image_Width_IllumGasdermin Image_Width_IllumMito Image_Width_IllumPM  \
# 0                       2160                  2160                2160
# 1                       2160                  2160                2160
# 2                       2160                  2160                2160
# 3                       2160                  2160                2160
# 4                       2160                  2160                2160
#
#   Image_Width_IllumRNA Image_Width_OrigDNA Image_Width_OrigER  \
# 0                 2160                2160               2160
# 1                 2160                2160               2160
# 2                 2160                2160               2160
# 3                 2160                2160               2160
# 4                 2160                2160               2160
#
#    Image_Width_OrigGasdermin  Image_Width_OrigMito  Image_Width_OrigPM  \
# 0                       2160                  2160                2160
# 1                       2160                  2160                2160
# 2                       2160                  2160                2160
# 3                       2160                  2160                2160
# 4                       2160                  2160                2160
#
#    Image_Width_OrigRNA
# 0                 2160
# 1                 2160
# 2                 2160
# 3                 2160
# 4                 2160
#
# [5 rows x 309 columns]

# %% [markdown]
# ## Extract image features from sqlite file

# %%
image_features_df = extract_utils.extract_image_features(image_feature_categories, image_df, image_cols, strata)

print(image_features_df.shape)
image_features_df.head()
# Out:
# (960, 195)
#    ImageNumber                        Image_Metadata_Plate  \
# 0            1  70117_20230118MM1_CellPainting_A700_20X_V1
# 1            2  70117_20230118MM1_CellPainting_A700_20X_V1
# 2            3  70117_20230118MM1_CellPainting_A700_20X_V1
# 3            4  70117_20230118MM1_CellPainting_A700_20X_V1
# 4            5  70117_20230118MM1_CellPainting_A700_20X_V1
#
#   Image_Metadata_Well  Image_ImageQuality_Correlation_CorrDNA_20  \
# 0                 A13                                   0.403882
# 1                 A13                                   0.291322
# 2                 A13                                   0.371845
# 3                 A13                                   0.375755
# 4                 A13                                   0.401941
#
#    Image_ImageQuality_Correlation_CorrER_20  \
# 0                                  0.434506
# 1                                  0.541198
# 2                                  0.252259
# 3                                  0.817931
# 4                                  0.131970
#
#    Image_ImageQuality_Correlation_CorrGasdermin_20  \
# 0                                         0.542825
# 1                                         0.600939
# 2                                         0.009633
# 3                                         0.277198
# 4                                         0.507040
#
#    Image_ImageQuality_Correlation_CorrMito_20  \
# 0                                    0.573529
# 1                                    0.599302
# 2                                    0.505273
# 3                                    0.604730
# 4                                    0.480633
#
#    Image_ImageQuality_Correlation_CorrPM_20  \
# 0                                  0.597844
# 1                                  0.666980
# 2                                  0.589347
# 3                                  0.613117
# 4                                  0.624985
#
#    Image_ImageQuality_Correlation_CorrRNA_20  \
# 0                                   0.314772
# 1                                   0.399502
# 2                                   0.441325
# 3                                   0.766828
# 4                                   0.364825
#
#    Image_ImageQuality_Correlation_OrigDNA_20  ...  \
# 0                                   0.402339  ...
# 1                                   0.308004  ...
# 2                                   0.374518  ...
# 3                                   0.394779  ...
# 4                                   0.413676  ...
#
#    Image_ImageQuality_TotalIntensity_CorrGasdermin  \
# 0                                     48879.050781
# 1                                     57369.070312
# 2                                     54433.957031
# 3                                     55847.441406
# 4                                     46019.976562
#
#    Image_ImageQuality_TotalIntensity_CorrMito  \
# 0                                34841.144531
# 1                                39998.722656
# 2                                38906.957031
# 3                                38892.527344
# 4                                32674.126953
#
#    Image_ImageQuality_TotalIntensity_CorrPM  \
# 0                              48721.179688
# 1                              63881.996094
# 2                              54597.066406
# 3                              53088.859375
# 4                              43813.699219
#
#    Image_ImageQuality_TotalIntensity_CorrRNA  \
# 0                               47153.792969
# 1                               58803.937500
# 2                               51266.492188
# 3                               55621.476562
# 4                               40466.992188
#
#    Image_ImageQuality_TotalIntensity_OrigDNA  \
# 0                               63551.707031
# 1                               81538.945312
# 2                               71519.992188
# 3                               74082.757812
# 4                               55326.621094
#
#    Image_ImageQuality_TotalIntensity_OrigER  \
# 0                             107106.304688
# 1                             124476.578125
# 2                             111797.804688
# 3                             137921.578125
# 4                              92031.796875
#
#    Image_ImageQuality_TotalIntensity_OrigGasdermin  \
# 0                                     68543.257812
# 1                                     80636.500000
# 2                                     76578.726562
# 3                                     79080.132812
# 4                                     64688.136719
#
#    Image_ImageQuality_TotalIntensity_OrigMito  \
# 0                                48249.867188
# 1                                55319.164062
# 2                                53959.656250
# 3                                54155.644531
# 4                                45247.652344
#
#    Image_ImageQuality_TotalIntensity_OrigPM  \
# 0                              84069.125000
# 1                             111208.203125
# 2                              95429.734375
# 3                              92845.429688
# 4                              76171.968750
#
#    Image_ImageQuality_TotalIntensity_OrigRNA
# 0                               82692.421875
# 1                              104272.976562
# 2                               90756.078125
# 3                               99988.484375
# 4                               71476.976562
#
# [5 rows x 195 columns]

# %% [markdown]
# ## Merge platemap metadata with extracted image features

# %%
## Uses pycytominer annotate functionality to merge the platemap and image features and reorder the dataframe
image_features_df = annotate(
    profiles=image_features_df,
    platemap=platemap_df,
    join_on=["Metadata_well", "Image_Metadata_Well"],
    output_file="none",
)

# %% [markdown]
# ## Save image features data frame as `csv.gz` file

# %%
# Save image feature data as a csv
output(image_features_df, image_features_output_file)

print(image_features_df.shape)
image_features_df.head()
# Out:
# (960, 201)
#   Metadata_wellName  Metadata_row  Metadata_col  Metadata_alias  \
# 0               A13             1            13               1
# 1               A13             1            13               1
# 2               A13             1            13               1
# 3               A13             1            13               1
# 4               A13             1            13               1
#
#   Metadata_treatment Metadata_dose  \
# 0                LPS       10µg/ml
# 1                LPS       10µg/ml
# 2                LPS       10µg/ml
# 3                LPS       10µg/ml
# 4                LPS       10µg/ml
#
#                                Metadata_Plate Metadata_Well  ImageNumber  \
# 0  70117_20230118MM1_CellPainting_A700_20X_V1           A13            1
# 1  70117_20230118MM1_CellPainting_A700_20X_V1           A13            2
# 2  70117_20230118MM1_CellPainting_A700_20X_V1           A13            3
# 3  70117_20230118MM1_CellPainting_A700_20X_V1           A13            4
# 4  70117_20230118MM1_CellPainting_A700_20X_V1           A13            5
#
#    Image_ImageQuality_Correlation_CorrDNA_20  ...  \
# 0                                   0.403882  ...
# 1                                   0.291322  ...
# 2                                   0.371845  ...
# 3                                   0.375755  ...
# 4                                   0.401941  ...
#
#    Image_ImageQuality_TotalIntensity_CorrGasdermin  \
# 0                                     48879.050781
# 1                                     57369.070312
# 2                                     54433.957031
# 3                                     55847.441406
# 4                                     46019.976562
#
#    Image_ImageQuality_TotalIntensity_CorrMito  \
# 0                                34841.144531
# 1                                39998.722656
# 2                                38906.957031
# 3                                38892.527344
# 4                                32674.126953
#
#    Image_ImageQuality_TotalIntensity_CorrPM  \
# 0                              48721.179688
# 1                              63881.996094
# 2                              54597.066406
# 3                              53088.859375
# 4                              43813.699219
#
#    Image_ImageQuality_TotalIntensity_CorrRNA  \
# 0                               47153.792969
# 1                               58803.937500
# 2                               51266.492188
# 3                               55621.476562
# 4                               40466.992188
#
#    Image_ImageQuality_TotalIntensity_OrigDNA  \
# 0                               63551.707031
# 1                               81538.945312
# 2                               71519.992188
# 3                               74082.757812
# 4                               55326.621094
#
#    Image_ImageQuality_TotalIntensity_OrigER  \
# 0                             107106.304688
# 1                             124476.578125
# 2                             111797.804688
# 3                             137921.578125
# 4                              92031.796875
#
#    Image_ImageQuality_TotalIntensity_OrigGasdermin  \
# 0                                     68543.257812
# 1                                     80636.500000
# 2                                     76578.726562
# 3                                     79080.132812
# 4                                     64688.136719
#
#    Image_ImageQuality_TotalIntensity_OrigMito  \
# 0                                48249.867188
# 1                                55319.164062
# 2                                53959.656250
# 3                                54155.644531
# 4                                45247.652344
#
#    Image_ImageQuality_TotalIntensity_OrigPM  \
# 0                              84069.125000
# 1                             111208.203125
# 2                              95429.734375
# 3                              92845.429688
# 4                              76171.968750
#
#    Image_ImageQuality_TotalIntensity_OrigRNA
# 0                               82692.421875
# 1                              104272.976562
# 2                               90756.078125
# 3                               99988.484375
# 4                               71476.976562
#
# [5 rows x 201 columns]

# %% [markdown]
# ## View info of the dataframe

# %%
image_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 960 entries, 0 to 959
# Columns: 201 entries, Metadata_wellName to Image_ImageQuality_TotalIntensity_OrigRNA
# dtypes: float64(192), int64(4), object(5)
# memory usage: 1.5+ MB
